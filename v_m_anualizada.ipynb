# %% [markdown]
# # ID das variáveis:
# #### 0 = Dados do Brasil - ANTAQ
# #### 1 = Dados do Brasil - UNCTAD
# #### 2 = Dados do Mundo - UNCTAD

# %%
import pandas as pd

# %% [markdown]
# ### Intervalo de 2010 a 2013 no Brasil com dados da ANTAQ

# %%
data_0 = pd.read_excel('/content/tb_mov_cont_br_antaq.xlsx')
data_0
# Out:
#      Ano  Total de Movimentação Contêineres (Líquido)\nem toneladas (t)
# 0   2010                                       8.064838e+06
# 1   2011                                       9.635055e+06
# 2   2012                                       1.014930e+07
# 3   2013                                       1.045024e+07
# 4   2014                                       1.200230e+07
# 5   2015                                       1.240667e+07
# 6   2016                                       1.201487e+07
# 7   2017                                       1.251246e+07
# 8   2018                                       1.353484e+07
# 9   2019                                       1.401652e+07
# 10  2020                                       1.492799e+07
# 11  2021                                       1.647472e+07
# 12  2022                                       1.575309e+07
# 13  2023                                       1.446347e+07

# %%
# taxa de variação de 2010 a 2023 | admite-se: var = variação
var_periodo_0 = data_0['Total de Movimentação Contêineres (Líquido)\nem toneladas (t)'].pct_change(periods=13)
taxa_var_periodo_0 = var_periodo[13]
taxa_var_periodo_0
# Out:
# 0.7933987653130061

# %%
# utilizamos a regra da potenciação para extrair a raiz enésima do valor desejado | admite-se: pct = porcentagem
pct_media_anualizada_0 = (((1+taxa_var_periodo_0)**(1/14))-1)*100
pct_media_anualizada_0
# Out:
# 4.26049347974311

# %% [markdown]
# ### Intervalo de 2010 a 2022 no Brasil com dados da UNCTAD

# %%
data_1 = pd.read_csv('/content/tb_mov_cont_br_unctad.csv')
data_1
# Out:
#    Economy_Label  Year  TEU_Twenty_foot_Equivalent_Unit_Value
# 0         Brazil  2010                                7223103
# 1         Brazil  2011                                8037427
# 2         Brazil  2012                                8455525
# 3         Brazil  2013                                9214483
# 4         Brazil  2014                                9436275
# 5         Brazil  2015                                9263315
# 6         Brazil  2016                                8804079
# 7         Brazil  2017                                9380502
# 8         Brazil  2018                               10061925
# 9         Brazil  2019                               10704669
# 10        Brazil  2020                               10450632
# 11        Brazil  2021                               11801530
# 12        Brazil  2022                               11683239

# %%
# taxa de variação de 2010 a 2022 | admite-se: var = variação
var_periodo_1 = data_1['TEU_Twenty_foot_Equivalent_Unit_Value'].pct_change(periods=12)
taxa_var_periodo_1 = var_periodo_1[12]
taxa_var_periodo_1
# Out:
# 0.6174819880043245

# %%
# utilizamos a regra da potenciação para extrair a raiz enésima do valor desejado | admite-se: pct = porcentagem
pct_media_anualizada_1 = (((1+taxa_var_periodo_1)**(1/13))-1)*100
pct_media_anualizada_1
# Out:
# 3.7682692781233706

# %% [markdown]
# ### Intervalo de 2010 a 2022 no Mundo com dados da UNCTAD

# %%
data_2 = pd.read_csv('/content/tb_mov_cont_wlrd_unctad.csv')
data_2
# Out:
#    Economy_Label  Year  TEU_Twenty_foot_Equivalent_Unit_Value
# 0          World  2010                              544828190
# 1          World  2011                              590669404
# 2          World  2012                              620011493
# 3          World  2013                              640598987
# 4          World  2014                              671267200
# 5          World  2015                              680924719
# 6          World  2016                              697735292
# 7          World  2017                              743556328
# 8          World  2018                              780426769
# 9          World  2019                              800514594
# 10         World  2020                              791651659
# 11         World  2021                              848643495
# 12         World  2022                              852305736

# %%
# taxa de variação de 2010 a 2022 | admite-se: var = variação
var_periodo_2 = data_2['TEU_Twenty_foot_Equivalent_Unit_Value'].pct_change(periods=12)
taxa_var_periodo_2 = var_periodo_2[12]
taxa_var_periodo_2
# Out:
# 0.5643568957032123

# %%
# utilizamos a regra da potenciação para extrair a raiz enésima do valor desejado | admite-se: pct = porcentagem
pct_media_anualizada_2 = (((1+taxa_var_periodo_2)**(1/13))-1)*100
pct_media_anualizada_2
# Out:
# 3.502040267434925
